# %% [markdown]
# # Prem Hyp attention distribution

# %%
import os
import pickle
from tabulate import tabulate
from scipy.stats import ttest_ind
import numpy as np

cwd = os.getcwd().split(os.path.sep)
while cwd[-1] != "BertPlausibilityStudy":
    os.chdir("..")
    cwd = os.getcwd().split(os.path.sep)
dir = os.path.join(".cache", "plots", "e_snli", "entropy_study")
with open(os.path.join(dir, "attention_prem_hyp.pickle"), "rb") as f:
    attention = pickle.load(f)
with open(os.path.join(dir, "entropy_prem_hyp.pickle"), "rb") as f:
    entropy = pickle.load(f)

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from notebooks.plots_utils import plot_color_from_ax, default_plot_colormap

# %% [markdown]
# ## Visualisation of the maps

# %%
# %%capture
fig, axes = plt.subplots(1, 3, figsize=(30, 10))
plot_color_from_ax(attention["entailement"].mean(axis=-1), axes[0],
                   ylabel="layer",
                   xlabel="",
                   xstick=["premise", "hypothesis"],
                   title = "Entailement")

plot_color_from_ax(attention["neutral"].mean(axis=-1), axes[1],
                   ylabel="layer",
                   xlabel="",
                   xstick=["premise", "hypothesis"],
                   title = "Neutral")

plot_color_from_ax(attention["contradiction"].mean(axis=-1), axes[2],
                   ylabel="layer",
                   xlabel="",
                   xstick=["premise", "hypothesis"],
                   title = "Contradiction")


fig.savefig(os.path.join(os.getcwd(),".cache", "plots", "e_snli", "entropy_study", "prem_hyp_attention_study.png"))

# %%
fig

# %% [markdown]
# évaluation des p_value pour avoir une idée des p_value entre les différents

# %% [markdown]
# ## The different tests

# %% [markdown]
# creation of the table for the test

# %%
def p_value_signifiance(p):
    if p <= 0.001:
        return "* * *"
    elif p <= 0.01:
        return "* *"
    elif p <= 0.05:
        return "*"
    else :
        return "."


def create_table(test_label):
    table = [["Layer","T-Stats", "p-value", "signifiance"]]
    for i in range(12):
        row = [f"Layer {i+1}",
               np.round(test_label[0][i], 3), 
               np.round(test_label[1][i], 3), 
               p_value_signifiance(test_label[1][i])]
        table.append(row)
        
    return table

# %%
test_entailement = ttest_ind(attention["entailement"][:,0,:], attention["entailement"][:,1,:], axis=-1)
test_neutral = ttest_ind(attention["neutral"][:,0,:], attention["neutral"][:,1,:], axis=-1)
test_contradiction = ttest_ind(attention["contradiction"][:,0,:], attention["contradiction"][:,1,:], axis=-1)

# %%
print(tabulate(create_table(test_entailement), headers="firstrow"))
print()
print(tabulate(create_table(test_neutral), headers="firstrow"))
print()
print(tabulate(create_table(test_contradiction), headers="firstrow"))
# Out:
# Layer       T-Stats    p-value  signifiance
# --------  ---------  ---------  -------------
# Layer 1     130.841          0  * * *
# Layer 2     117.689          0  * * *
# Layer 3     129.012          0  * * *
# Layer 4     132.361          0  * * *
# Layer 5      65.249          0  * * *
# Layer 6      43.029          0  * * *
# Layer 7      46.449          0  * * *
# Layer 8      21.74           0  * * *
# Layer 9      35.756          0  * * *
# Layer 10     50.82           0  * * *
# Layer 11    -14.765          0  * * *
# Layer 12      6.4            0  * * *
#
# Layer       T-Stats    p-value  signifiance
# --------  ---------  ---------  -------------
# Layer 1      77.201          0  * * *
# Layer 2      68.415          0  * * *
# Layer 3      73.211          0  * * *
# Layer 4      75.765          0  * * *
# Layer 5      37.144          0  * * *
# Layer 6      21.101          0  * * *
# Layer 7      23.367          0  * * *
# Layer 8       5.358          0  * * *
# Layer 9       9.47           0  * * *
# Layer 10     21.019          0  * * *
# Layer 11    -27.145          0  * * *
# Layer 12     -7.856          0  * * *
#
# Layer       T-Stats    p-value  signifiance
# --------  ---------  ---------  -------------
# Layer 1     105.866          0  * * *
# Layer 2      91.388          0  * * *
# Layer 3      98.492          0  * * *
# Layer 4      98.385          0  * * *
# Layer 5      48.008          0  * * *
# Layer 6      34.131          0  * * *
# Layer 7      38.747          0  * * *
# Layer 8      24.09           0  * * *
# Layer 9      22.938          0  * * *
# Layer 10     37.71           0  * * *
# Layer 11   -132.992          0  * * *
# Layer 12   -101.13           0  * * *

# %% [markdown]
# il y a donc bien des différences significatives entre les différentes parties de la phrases peu import la couche et peu import le label
# - pour la label contradiction on a une forte concentration sur l'hypothèse à partir de la couche 12

# %% [markdown]
# ## Entropy on the prem and the hyp

# %%
# %%capture
fig, axes = plt.subplots(1, 3, figsize=(30, 10))
plot_color_from_ax(entropy["entailement"].mean(axis=-1), axes[0],
                   ylabel="layer",
                   xlabel="",
                   xstick=["premise", "hypothesis"],
                   title = "Entailement")

plot_color_from_ax(entropy["neutral"].mean(axis=-1), axes[1],
                   ylabel="layer",
                   xlabel="",
                   xstick=["premise", "hypothesis"],
                   title = "Neutral")

plot_color_from_ax(entropy["contradiction"].mean(axis=-1), axes[2],
                   ylabel="layer",
                   xlabel="",
                   xstick=["premise", "hypothesis"],
                   title = "Contradiction")


fig.savefig(os.path.join(os.getcwd(),".cache", "plots", "e_snli","entropy_study", "prem_hyp_entropy_study.png"))

# %%
fig

# %%
test_entailement = ttest_ind(entropy["entailement"][:,0,:], entropy["entailement"][:,1,:], axis=-1)
test_neutral = ttest_ind(entropy["neutral"][:,0,:], entropy["neutral"][:,1,:], axis=-1)
test_contradiction = ttest_ind(entropy["contradiction"][:,0,:], entropy["contradiction"][:,1,:], axis=-1)

# %%
print(tabulate(create_table(test_entailement), headers="firstrow"))
print()
print(tabulate(create_table(test_neutral), headers="firstrow"))
print()
print(tabulate(create_table(test_contradiction), headers="firstrow"))
# Out:
# Layer       T-Stats    p-value  signifiance
# --------  ---------  ---------  -------------
# Layer 1      -7.018      0      * * *
# Layer 2     -30.15       0      * * *
# Layer 3      -7.516      0      * * *
# Layer 4      -6.333      0      * * *
# Layer 5      15.842      0      * * *
# Layer 6      19.094      0      * * *
# Layer 7      20.057      0      * * *
# Layer 8      23.539      0      * * *
# Layer 9      20.387      0      * * *
# Layer 10     15.115      0      * * *
# Layer 11     -2.547      0.011  *
# Layer 12    -21.526      0      * * *
#
# Layer       T-Stats    p-value  signifiance
# --------  ---------  ---------  -------------
# Layer 1       3.393      0.001  * * *
# Layer 2     -44.357      0      * * *
# Layer 3      -8.347      0      * * *
# Layer 4      -2.336      0.02   *
# Layer 5      14.737      0      * * *
# Layer 6      17.986      0      * * *
# Layer 7      21.081      0      * * *
# Layer 8      21.66       0      * * *
# Layer 9      23.133      0      * * *
# Layer 10     20.848      0      * * *
# Layer 11     10.864      0      * * *
# Layer 12    -12.087      0      * * *
#
# Layer       T-Stats    p-value  signifiance
# --------  ---------  ---------  -------------
# Layer 1      -2.676      0.007  * *
# Layer 2     -33.49       0      * * *
# Layer 3       2.867      0.004  * *
# Layer 4       0.822      0.411  .
# Layer 5      16.563      0      * * *
# Layer 6      18.163      0      * * *
# Layer 7      20.908      0      * * *
# Layer 8      18.592      0      * * *
# Layer 9      20.151      0      * * *
# Layer 10     14.104      0      * * *
# Layer 11     67.542      0      * * *
# Layer 12     43.417      0      * * *

# %% [markdown]
# Nous avons ainsi des distributions qui sont déséquilibrées. Nous avons plus d'attention sur la premise mais cela est du à une entropie qui est plus forte
